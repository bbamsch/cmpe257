# %%
######################
# Process MIDI Files #
######################

from music21 import converter
from music21 import instrument
from music21 import chord
from music21 import note
import glob
import json
import os

# VARS
DATA_GLOB = "data/pokemon/PkmRB/PkmRB-Battle1.mid"
MODEL_DIR = "model/pokemon/PkmRB-V1"
NOTES_FILE = "%s/%s" % (MODEL_DIR, "notes.json")

NOTES_BY_FILE = []
NOTES = set()

for input_file in glob.glob(DATA_GLOB):
    print("Ingesting... %s" % input_file)
    
    midi = converter.parse(input_file)
    parts = instrument.partitionByInstrument(midi)
    if parts:
        notes_to_parse = parts.parts[0].recurse()
    else:
        notes_to_parse = midi.flat.notes
    
    combined_notes = []
    file_notes = []
    last_offset = 0.0
    
    note_num = 1
    for element in notes_to_parse:
        print(type(element))
        
        if isinstance(element, note.Note):
            print("%02d | %02.4f | %s | %s" % (note_num, element.offset, element.duration.type, element.fullName))
            note_num += 1
            
        if (note_num > 200):
            break

    NOTES_BY_FILE.append(file_notes)
    NOTES.update(set(file_notes))

NOTES = sorted(NOTES)

if not os.path.exists(os.path.dirname(NOTES_FILE)):
    os.makedirs(os.path.dirname(NOTES_FILE))
with open(NOTES_FILE, 'w') as note_file:
    json.dump(NOTES, note_file)
# Out:
# Ingesting... data/pokemon/PkmRB/PkmRB-Battle1.mid
# <class 'music21.stream.Part'>
# <class 'music21.instrument.Instrument'>
# <class 'music21.tempo.MetronomeMark'>
# <class 'music21.key.Key'>
# <class 'music21.key.Key'>
# <class 'music21.key.Key'>
# <class 'music21.meter.TimeSignature'>
# <class 'music21.meter.TimeSignature'>
# <class 'music21.meter.TimeSignature'>
# <class 'music21.note.Note'>
# 01 | 0.0000 | 16th | C in octave 5 16th Note
# <class 'music21.note.Note'>
# 02 | 0.0000 | 16th | G in octave 5 16th Note
# <class 'music21.note.Note'>
# 03 | 0.0000 | 16th | C-sharp in octave 4 16th Note
# <class 'music21.note.Note'>
# 04 | 0.2500 | 16th | B in octave 4 16th Note
# <class 'music21.note.Note'>
# 05 | 0.2500 | 16th | F-sharp in octave 5 16th Note
# <class 'music21.note.Rest'>
# <class 'music21.note.Note'>
# 06 | 0.5000 | 16th | B-flat in octave 4 16th Note
# <class 'music21.note.Note'>
# 07 | 0.5000 | 16th | F in octave 5 16th Note
# <class 'music21.note.Note'>
# 08 | 0.5000 | 16th | C-sharp in octave 4 16th Note
# <class 'music21.note.Note'>
# 09 | 0.7500 | 16th | A in octave 4 16th Note
# <class 'music21.note.Note'>
# 10 | 0.7500 | 16th | G in octave 6 16th Note
# <class 'music21.note.Note'>
# 11 | 0.7500 | 16th | C in octave 4 16th Note
# <class 'music21.note.Note'>
# 12 | 1.0000 | 16th | B-flat in octave 4 16th Note
# <class 'music21.note.Note'>
# 13 | 1.0000 | 16th | G in octave 5 16th Note
# <class 'music21.note.Note'>
# 14 | 1.0000 | 16th | D in octave 4 16th Note
# <class 'music21.note.Note'>
# 15 | 1.2500 | 16th | A in octave 4 16th Note
# <class 'music21.note.Note'>
# 16 | 1.2500 | 16th | F-sharp in octave 5 16th Note
# <class 'music21.note.Rest'>
# <class 'music21.note.Note'>
# 17 | 1.5000 | 16th | G-sharp in octave 4 16th Note
# <class 'music21.note.Note'>
# 18 | 1.5000 | 16th | F in octave 5 16th Note
# <class 'music21.note.Note'>
# 19 | 1.5000 | 16th | D in octave 4 16th Note
# <class 'music21.note.Note'>
# 20 | 1.7500 | 16th | G in octave 4 16th Note
# <class 'music21.note.Note'>
# 21 | 1.7500 | 16th | G in octave 6 16th Note
# <class 'music21.note.Note'>
# 22 | 1.7500 | 16th | C in octave 4 16th Note
# <class 'music21.note.Note'>
# 23 | 2.0000 | 16th | G-sharp in octave 4 16th Note
# <class 'music21.note.Note'>
# 24 | 2.0000 | 16th | G in octave 5 16th Note
# <class 'music21.note.Note'>
# 25 | 2.0000 | 16th | E-flat in octave 4 16th Note
# <class 'music21.note.Note'>
# 26 | 2.2500 | 16th | G in octave 4 16th Note
# <class 'music21.note.Note'>
# 27 | 2.2500 | 16th | F-sharp in octave 5 16th Note
# <class 'music21.note.Rest'>
# <class 'music21.note.Note'>
# 28 | 2.5000 | 16th | F-sharp in octave 4 16th Note
# <class 'music21.note.Note'>
# 29 | 2.5000 | 16th | F in octave 5 16th Note
# <class 'music21.note.Note'>
# 30 | 2.5000 | 16th | E-flat in octave 4 16th Note
# <class 'music21.note.Note'>
# 31 | 2.7500 | 16th | F in octave 4 16th Note
# <class 'music21.note.Note'>
# 32 | 2.7500 | 16th | G in octave 6 16th Note
# <class 'music21.note.Note'>
# 33 | 2.7500 | 16th | C in octave 4 16th Note
# <class 'music21.note.Note'>
# 34 | 3.0000 | 16th | F-sharp in octave 4 16th Note
# <class 'music21.note.Note'>
# 35 | 3.0000 | 16th | G in octave 5 16th Note
# <class 'music21.note.Note'>
# 36 | 3.0000 | 16th | E in octave 4 16th Note
# <class 'music21.note.Note'>
# 37 | 3.2500 | 16th | F in octave 4 16th Note
# <class 'music21.note.Note'>
# 38 | 3.2500 | 16th | F-sharp in octave 5 16th Note
# <class 'music21.note.Rest'>
# <class 'music21.note.Note'>
# 39 | 3.5000 | 16th | E in octave 4 16th Note
# <class 'music21.note.Note'>
# 40 | 3.5000 | 16th | F in octave 5 16th Note
# <class 'music21.note.Note'>
# 41 | 3.5000 | 16th | E in octave 4 16th Note
# <class 'music21.note.Note'>
# 42 | 3.7500 | 16th | E-flat in octave 4 16th Note
# <class 'music21.note.Note'>
# 43 | 3.7500 | 16th | G in octave 6 16th Note
# <class 'music21.note.Note'>
# 44 | 3.7500 | 16th | C in octave 4 16th Note
# <class 'music21.note.Note'>
# 45 | 4.0000 | 16th | E in octave 4 16th Note
# <class 'music21.note.Note'>
# 46 | 4.0000 | 16th | G in octave 5 16th Note
# <class 'music21.note.Note'>
# 47 | 4.0000 | 16th | F in octave 4 16th Note
# <class 'music21.note.Note'>
# 48 | 4.2500 | 16th | E-flat in octave 4 16th Note
# <class 'music21.note.Note'>
# 49 | 4.2500 | 16th | F-sharp in octave 5 16th Note
# <class 'music21.note.Rest'>
# <class 'music21.note.Note'>
# 50 | 4.5000 | 16th | D in octave 4 16th Note
# <class 'music21.note.Note'>
# 51 | 4.5000 | 16th | F in octave 5 16th Note
# <class 'music21.note.Note'>
# 52 | 4.5000 | 16th | F in octave 4 16th Note
# <class 'music21.note.Note'>
# 53 | 4.7500 | 16th | C-sharp in octave 4 16th Note
# <class 'music21.note.Note'>
# 54 | 4.7500 | 16th | G in octave 6 16th Note
# <class 'music21.note.Note'>
# 55 | 4.7500 | 16th | C in octave 4 16th Note
# <class 'music21.note.Note'>
# 56 | 5.0000 | 16th | D in octave 4 16th Note
# <class 'music21.note.Note'>
# 57 | 5.0000 | 16th | G in octave 5 16th Note
# <class 'music21.note.Note'>
# 58 | 5.0000 | 16th | F-sharp in octave 4 16th Note
# <class 'music21.note.Note'>
# 59 | 5.2500 | 16th | C-sharp in octave 4 16th Note
# <class 'music21.note.Note'>
# 60 | 5.2500 | 16th | F-sharp in octave 5 16th Note
# <class 'music21.note.Rest'>
# <class 'music21.note.Note'>
# 61 | 5.5000 | 16th | C in octave 4 16th Note
# <class 'music21.note.Note'>
# 62 | 5.5000 | 16th | F in octave 5 16th Note
# <class 'music21.note.Note'>
# 63 | 5.5000 | 16th | F-sharp in octave 4 16th Note
# <class 'music21.note.Note'>
# 64 | 5.7500 | 16th | B in octave 3 16th Note
# <class 'music21.note.Note'>
# 65 | 5.7500 | 16th | G in octave 6 16th Note
# <class 'music21.note.Note'>
# 66 | 5.7500 | 16th | C in octave 4 16th Note
# <class 'music21.note.Note'>
# 67 | 6.0000 | 16th | C in octave 4 16th Note
# <class 'music21.note.Note'>
# 68 | 6.0000 | 16th | G in octave 5 16th Note
# <class 'music21.note.Note'>
# 69 | 6.0000 | 16th | G in octave 4 16th Note
# <class 'music21.note.Note'>
# 70 | 6.2500 | 16th | B in octave 3 16th Note
# <class 'music21.note.Note'>
# 71 | 6.2500 | 16th | F-sharp in octave 5 16th Note
# <class 'music21.note.Rest'>
# <class 'music21.note.Note'>
# 72 | 6.5000 | 16th | B-flat in octave 3 16th Note
# <class 'music21.note.Note'>
# 73 | 6.5000 | 16th | F in octave 5 16th Note
# <class 'music21.note.Note'>
# 74 | 6.5000 | 16th | G in octave 4 16th Note
# <class 'music21.note.Note'>
# 75 | 6.7500 | 16th | A in octave 3 16th Note
# <class 'music21.note.Note'>
# 76 | 6.7500 | 16th | G in octave 6 16th Note
# <class 'music21.note.Note'>
# 77 | 6.7500 | 16th | C in octave 4 16th Note
# <class 'music21.note.Note'>
# 78 | 7.0000 | 16th | B-flat in octave 3 16th Note
# <class 'music21.note.Note'>
# 79 | 7.0000 | 16th | G in octave 5 16th Note
# <class 'music21.note.Note'>
# 80 | 7.0000 | eighth | B-flat in octave 3 Eighth Note
# <class 'music21.note.Note'>
# 81 | 7.2500 | 16th | B in octave 3 16th Note
# <class 'music21.note.Note'>
# 82 | 7.2500 | 16th | F-sharp in octave 5 16th Note
# <class 'music21.note.Note'>
# 83 | 7.5000 | 16th | C in octave 4 16th Note
# <class 'music21.note.Note'>
# 84 | 7.5000 | 16th | F in octave 5 16th Note
# <class 'music21.note.Note'>
# 85 | 7.5000 | eighth | B in octave 3 Eighth Note
# <class 'music21.note.Note'>
# 86 | 7.7500 | 16th | C-sharp in octave 4 16th Note
# <class 'music21.note.Note'>
# 87 | 7.7500 | 16th | G in octave 6 16th Note
# <class 'music21.note.Note'>
# 88 | 8.0000 | 16th | G in octave 4 16th Note
# <class 'music21.note.Note'>
# 89 | 8.0000 | quarter | G in octave 5 Quarter Note
# <class 'music21.note.Note'>
# 90 | 8.0000 | eighth | C in octave 4 Eighth Note
# <class 'music21.note.Rest'>
# <class 'music21.note.Note'>
# 91 | 8.5000 | eighth | G in octave 4 Eighth Note
# <class 'music21.note.Rest'>
# <class 'music21.note.Note'>
# 92 | 9.0000 | eighth | C in octave 4 Eighth Note
# <class 'music21.note.Note'>
# 93 | 9.5000 | 16th | E in octave 4 16th Note
# <class 'music21.note.Note'>
# 94 | 9.5000 | quarter | G in octave 4 Quarter Note
# <class 'music21.note.Note'>
# 95 | 9.5000 | eighth | G in octave 4 Eighth Note
# <class 'music21.note.Rest'>
# <class 'music21.note.Note'>
# 96 | 10.0000 | eighth | C in octave 4 Eighth Note
# <class 'music21.note.Rest'>
# <class 'music21.note.Note'>
# 97 | 10.5000 | eighth | G in octave 4 Eighth Note
# <class 'music21.note.Note'>
# 98 | 11.0000 | 16th | E-flat in octave 4 16th Note
# <class 'music21.note.Note'>
# 99 | 11.0000 | quarter | G in octave 4 Quarter Note
# <class 'music21.note.Note'>
# 100 | 11.0000 | eighth | C in octave 4 Eighth Note
# <class 'music21.note.Rest'>
# <class 'music21.note.Note'>
# 101 | 11.5000 | eighth | G in octave 4 Eighth Note
# <class 'music21.note.Rest'>
# <class 'music21.note.Note'>
# 102 | 12.0000 | eighth | C in octave 4 Eighth Note
# <class 'music21.note.Note'>
# 103 | 12.5000 | eighth | G in octave 4 Eighth Note
# <class 'music21.note.Note'>
# 104 | 13.0000 | eighth | C in octave 4 Eighth Note
# <class 'music21.note.Note'>
# 105 | 13.5000 | eighth | G in octave 4 Eighth Note
# <class 'music21.note.Note'>
# 106 | 14.0000 | 16th | C-sharp in octave 4 16th Note
# <class 'music21.note.Note'>
# 107 | 14.0000 | quarter | G in octave 4 Quarter Note
# <class 'music21.note.Note'>
# 108 | 14.0000 | eighth | C in octave 4 Eighth Note
# <class 'music21.note.Rest'>
# <class 'music21.note.Note'>
# 109 | 14.5000 | eighth | G in octave 4 Eighth Note
# <class 'music21.note.Rest'>
# <class 'music21.note.Note'>
# 110 | 15.0000 | eighth | C in octave 4 Eighth Note
# <class 'music21.note.Note'>
# 111 | 15.5000 | eighth | G in octave 4 Eighth Note
# <class 'music21.note.Note'>
# 112 | 16.0000 | eighth | C-sharp in octave 4 Eighth Note
# <class 'music21.note.Note'>
# 113 | 16.5000 | eighth | G-sharp in octave 4 Eighth Note
# <class 'music21.note.Note'>
# 114 | 17.0000 | eighth | C-sharp in octave 4 Eighth Note
# <class 'music21.note.Note'>
# 115 | 17.5000 | 16th | E in octave 4 16th Note
# <class 'music21.note.Note'>
# 116 | 17.5000 | quarter | G in octave 4 Quarter Note
# <class 'music21.note.Note'>
# 117 | 17.5000 | eighth | C-sharp in octave 4 Eighth Note
# <class 'music21.note.Rest'>
# <class 'music21.note.Note'>
# 118 | 18.0000 | eighth | G-sharp in octave 4 Eighth Note
# <class 'music21.note.Rest'>
# <class 'music21.note.Note'>
# 119 | 18.5000 | eighth | B-flat in octave 4 Eighth Note
# <class 'music21.note.Note'>
# 120 | 19.0000 | 16th | E-flat in octave 4 16th Note
# <class 'music21.note.Note'>
# 121 | 19.0000 | quarter | G in octave 4 Quarter Note
# <class 'music21.note.Note'>
# 122 | 19.0000 | eighth | G-sharp in octave 4 Eighth Note
# <class 'music21.note.Rest'>
# <class 'music21.note.Note'>
# 123 | 19.5000 | eighth | G in octave 4 Eighth Note
# <class 'music21.note.Rest'>
# <class 'music21.note.Note'>
# 124 | 20.0000 | eighth | C-sharp in octave 4 Eighth Note
# <class 'music21.note.Note'>
# 125 | 20.5000 | eighth | G-sharp in octave 4 Eighth Note
# <class 'music21.note.Note'>
# 126 | 21.0000 | eighth | C-sharp in octave 4 Eighth Note
# <class 'music21.note.Note'>
# 127 | 21.5000 | complex | C-sharp in octave 4 Half tied to Eighth (2 1/2 total QL) Note
# <class 'music21.note.Note'>
# 128 | 21.5000 | complex | F-sharp in octave 4 Half tied to Eighth (2 1/2 total QL) Note
# <class 'music21.note.Note'>
# 129 | 21.5000 | eighth | C-sharp in octave 4 Eighth Note
# <class 'music21.note.Note'>
# 130 | 22.0000 | eighth | G-sharp in octave 4 Eighth Note
# <class 'music21.note.Note'>
# 131 | 22.5000 | eighth | B-flat in octave 4 Eighth Note
# <class 'music21.note.Note'>
# 132 | 23.0000 | eighth | G-sharp in octave 4 Eighth Note
# <class 'music21.note.Note'>
# 133 | 23.5000 | eighth | F in octave 4 Eighth Note
# <class 'music21.note.Note'>
# 134 | 24.0000 | 16th | G in octave 4 16th Note
# <class 'music21.note.Note'>
# 135 | 24.0000 | quarter | G in octave 4 Quarter Note
# <class 'music21.note.Note'>
# 136 | 24.0000 | eighth | C in octave 4 Eighth Note
# <class 'music21.note.Rest'>
# <class 'music21.note.Note'>
# 137 | 24.5000 | eighth | G in octave 4 Eighth Note
# <class 'music21.note.Rest'>
# <class 'music21.note.Note'>
# 138 | 25.0000 | eighth | C in octave 4 Eighth Note
# <class 'music21.note.Note'>
# 139 | 25.5000 | 16th | E in octave 4 16th Note
# <class 'music21.note.Note'>
# 140 | 25.5000 | quarter | G in octave 4 Quarter Note
# <class 'music21.note.Note'>
# 141 | 25.5000 | eighth | G in octave 4 Eighth Note
# <class 'music21.note.Rest'>
# <class 'music21.note.Note'>
# 142 | 26.0000 | eighth | C in octave 4 Eighth Note
# <class 'music21.note.Rest'>
# <class 'music21.note.Note'>
# 143 | 26.5000 | eighth | G in octave 4 Eighth Note
# <class 'music21.note.Note'>
# 144 | 27.0000 | 16th | E-flat in octave 4 16th Note
# <class 'music21.note.Note'>
# 145 | 27.0000 | quarter | G in octave 4 Quarter Note
# <class 'music21.note.Note'>
# 146 | 27.0000 | eighth | C in octave 4 Eighth Note
# <class 'music21.note.Rest'>
# <class 'music21.note.Note'>
# 147 | 27.5000 | eighth | G in octave 4 Eighth Note
# <class 'music21.note.Rest'>
# <class 'music21.note.Note'>
# 148 | 28.0000 | eighth | C in octave 4 Eighth Note
# <class 'music21.note.Note'>
# 149 | 28.5000 | eighth | G in octave 4 Eighth Note
# <class 'music21.note.Note'>
# 150 | 29.0000 | eighth | C in octave 4 Eighth Note
# <class 'music21.note.Note'>
# 151 | 29.5000 | eighth | G in octave 4 Eighth Note
# <class 'music21.note.Note'>
# 152 | 30.0000 | 16th | C-sharp in octave 4 16th Note
# <class 'music21.note.Note'>
# 153 | 30.0000 | quarter | G in octave 4 Quarter Note
# <class 'music21.note.Note'>
# 154 | 30.0000 | eighth | C in octave 4 Eighth Note
# <class 'music21.note.Rest'>
# <class 'music21.note.Note'>
# 155 | 30.5000 | eighth | G in octave 4 Eighth Note
# <class 'music21.note.Rest'>
# <class 'music21.note.Note'>
# 156 | 31.0000 | eighth | C in octave 4 Eighth Note
# <class 'music21.note.Note'>
# 157 | 31.5000 | eighth | G in octave 4 Eighth Note
# <class 'music21.note.Note'>
# 158 | 32.0000 | eighth | C-sharp in octave 4 Eighth Note
# <class 'music21.note.Note'>
# 159 | 32.5000 | eighth | G-sharp in octave 4 Eighth Note
# <class 'music21.note.Note'>
# 160 | 33.0000 | eighth | C-sharp in octave 4 Eighth Note
# <class 'music21.note.Note'>
# 161 | 33.5000 | 16th | E in octave 4 16th Note
# <class 'music21.note.Note'>
# 162 | 33.5000 | quarter | G in octave 4 Quarter Note
# <class 'music21.note.Note'>
# 163 | 33.5000 | eighth | C-sharp in octave 4 Eighth Note
# <class 'music21.note.Rest'>
# <class 'music21.note.Note'>
# 164 | 34.0000 | eighth | G-sharp in octave 4 Eighth Note
# <class 'music21.note.Rest'>
# <class 'music21.note.Note'>
# 165 | 34.5000 | eighth | B-flat in octave 4 Eighth Note
# <class 'music21.note.Note'>
# 166 | 35.0000 | 16th | E-flat in octave 4 16th Note
# <class 'music21.note.Note'>
# 167 | 35.0000 | quarter | G in octave 4 Quarter Note
# <class 'music21.note.Note'>
# 168 | 35.0000 | eighth | G-sharp in octave 4 Eighth Note
# <class 'music21.note.Rest'>
# <class 'music21.note.Note'>
# 169 | 35.5000 | eighth | G in octave 4 Eighth Note
# <class 'music21.note.Rest'>
# <class 'music21.note.Note'>
# 170 | 36.0000 | eighth | C-sharp in octave 4 Eighth Note
# <class 'music21.note.Note'>
# 171 | 36.5000 | eighth | G-sharp in octave 4 Eighth Note
# <class 'music21.note.Note'>
# 172 | 37.0000 | eighth | C-sharp in octave 4 Eighth Note
# <class 'music21.note.Note'>
# 173 | 37.5000 | quarter | C-sharp in octave 4 Quarter Note
# <class 'music21.note.Note'>
# 174 | 37.5000 | quarter | G in octave 4 Quarter Note
# <class 'music21.note.Note'>
# 175 | 37.5000 | eighth | C-sharp in octave 4 Eighth Note
# <class 'music21.note.Note'>
# 176 | 38.0000 | eighth | G-sharp in octave 4 Eighth Note
# <class 'music21.note.Rest'>
# <class 'music21.note.Rest'>
# <class 'music21.note.Note'>
# 177 | 38.5000 | eighth | B-flat in octave 4 Eighth Note
# <class 'music21.note.Note'>
# 178 | 39.0000 | eighth | G-sharp in octave 4 Eighth Note
# <class 'music21.note.Note'>
# 179 | 39.5000 | eighth | F in octave 4 Eighth Note
# <class 'music21.note.Note'>
# 180 | 40.0000 | 16th | C-sharp in octave 4 16th Note
# <class 'music21.note.Note'>
# 181 | 40.0000 | quarter | G in octave 4 Dotted Quarter Note
# <class 'music21.note.Note'>
# 182 | 40.0000 | eighth | C in octave 4 Eighth Note
# <class 'music21.note.Note'>
# 183 | 40.2500 | 16th | D in octave 4 16th Note
# <class 'music21.note.Note'>
# 184 | 40.5000 | 16th | C-sharp in octave 4 16th Note
# <class 'music21.note.Note'>
# 185 | 40.5000 | eighth | G in octave 4 Eighth Note
# <class 'music21.note.Note'>
# 186 | 40.7500 | 16th | C in octave 4 16th Note
# <class 'music21.note.Note'>
# 187 | 41.0000 | 16th | C-sharp in octave 4 16th Note
# <class 'music21.note.Note'>
# 188 | 41.0000 | eighth | C in octave 4 Eighth Note
# <class 'music21.note.Note'>
# 189 | 41.2500 | 16th | D in octave 4 16th Note
# <class 'music21.note.Note'>
# 190 | 41.5000 | 16th | C-sharp in octave 4 16th Note
# <class 'music21.note.Note'>
# 191 | 41.5000 | quarter | F-sharp in octave 4 Dotted Quarter Note
# <class 'music21.note.Note'>
# 192 | 41.5000 | eighth | G in octave 4 Eighth Note
# <class 'music21.note.Note'>
# 193 | 41.7500 | 16th | C in octave 4 16th Note
# <class 'music21.note.Note'>
# 194 | 42.0000 | 16th | C-sharp in octave 4 16th Note
# <class 'music21.note.Note'>
# 195 | 42.0000 | eighth | C in octave 4 Eighth Note
# <class 'music21.note.Note'>
# 196 | 42.2500 | 16th | D in octave 4 16th Note
# <class 'music21.note.Note'>
# 197 | 42.5000 | 16th | E-flat in octave 4 16th Note
# <class 'music21.note.Note'>
# 198 | 42.5000 | eighth | G in octave 4 Eighth Note
# <class 'music21.note.Note'>
# 199 | 42.7500 | 16th | D in octave 4 16th Note
# <class 'music21.note.Note'>
# 200 | 43.0000 | 16th | C-sharp in octave 4 16th Note

# %%
import uuid
from music21 import note, chord, stream

MIDI_OUTPUT_DIRECTORY = "experimental/pokemon/PkmRB-V1/"

output = NOTES_BY_FILE[0]
    
offset = 0
output_notes = []
for note_pattern in output:
    if ('.' in note_pattern) or note_pattern.isdigit():
        notes_in_chord = note_pattern.split('.')
        notes = []
        for current_note in notes_in_chord:
            new_note = note.Note(int(current_note))
            new_note = storedInstrument = instrument.Piano()
            notes.append(new_note)
        new_chord = chord.Chord(notes)
        new_chord.offset = offset
        output_notes.append(new_chord)
    else:
        new_note = note.Note(note_pattern)
        new_note.offset = offset
        new_note.storedInstrument = instrument.Piano()
        output_notes.append(new_note)
        
    offset += 0.5
    
if not os.path.exists(os.path.dirname(MIDI_OUTPUT_DIRECTORY)):
    os.makedirs(os.path.dirname(MIDI_OUTPUT_DIRECTORY))
midi_stream = stream.Stream(output_notes)
midi_stream.write('midi', fp="%s/%s.%s.%s" % (MIDI_OUTPUT_DIRECTORY, "exp1", uuid.uuid4(), "mid"))
# Out:
# 'experimental/pokemon/PkmRB-V1//exp1.66f3faa7-2010-4fb9-adb2-5b6a48f8cee1.mid'

# %%
########################
# Build Note Sequences #
########################

import numpy
from keras.utils import np_utils

NOTES_FILE = None
SEQUENCE_LENGTH = 80
X = []
y = []

# Load Notes from disk if desired
if NOTES_FILE:
    with open(NOTES_FILE, 'r') as notes_file:
        NOTES = json.loads(notes_file.read())

NOTE_TO_INT = dict((note, number) for number, note in enumerate(NOTES))
INT_TO_NOTE = dict((number, note) for number, note in enumerate(NOTES))

for notes in NOTES_BY_FILE:
    for i in range(0, len(notes) - SEQUENCE_LENGTH, 1):
        input_sequence = notes[i:i + SEQUENCE_LENGTH] # N Input Notes
        output_sequence = notes[i + SEQUENCE_LENGTH] # 1 Output Note
        
        X.append([NOTE_TO_INT[c] for c in input_sequence])
        y.append(NOTE_TO_INT[output_sequence])
        
N_SEQUENCES = len(X)
N_VOCAB = len(NOTES)

print("Num Sequences: %d" % N_SEQUENCES)
print("Num Vocab: %d" % N_VOCAB)

X = numpy.reshape(X, (N_SEQUENCES, SEQUENCE_LENGTH, 1)) / N_VOCAB
y = np_utils.to_categorical(y)
# Out:
# Num Sequences: 25524
# Num Vocab: 56

# %%
#######################
# Construct the Model #
#######################

from keras.models import Sequential
from keras.layers import Dense
from keras.layers import Dropout
from keras.layers import LSTM
from keras.layers import Activation
from keras.callbacks import ModelCheckpoint

MODEL_FILE = "%s/%s" % (MODEL_DIR, "LSTM-L256-L128-S80-weights-improvements-013-2.9983.hdf5")
CHECKPOINT_FILE = MODEL_FILE

model = Sequential()
model.add(LSTM(
    256,
    input_shape=(X.shape[1], X.shape[2]),
    return_sequences=True
))
model.add(Dropout(0.3))
model.add(LSTM(128))
model.add(Dropout(0.3))
model.add(Dense(N_VOCAB))
model.add(Activation('softmax'))
if (CHECKPOINT_FILE):
    model.load_weights(CHECKPOINT_FILE)
model.compile(loss='categorical_crossentropy', optimizer='adam')

# %%
##################
# Produce a MIDI #
##################

import uuid
from music21 import note, chord, stream

MIDI_OUTPUT_DIRECTORY = "experimental/pokemon/PkmRB-V1/"

SEED_INPUT_SEQUENCE = X[numpy.random.randint(0, len(X))] * N_VOCAB
SEED_SEQUENCE = [INT_TO_NOTE[numpy.round(number[0])] for number in SEED_INPUT_SEQUENCE]

for i in range(500):
    input_sequence = numpy.reshape(pattern, (1, len(pattern), 1))
    output_sequence = model.predict(input_sequence, verbose=0)
    
    number = numpy.argmax(output_sequence)
    result = INT_TO_NOTE[number]
    output.append(result)
    
    pattern = numpy.append(pattern, number)
    pattern = pattern[1:]
    
offset = 0
output_notes = []
for note_pattern in output:
    if ('.' in note_pattern) or note_pattern.isdigit():
        notes_in_chord = note_pattern.split('.')
        notes = []
        for current_note in notes_in_chord:
            new_note = note.Note(int(current_note))
            new_note = storedInstrument = instrument.Piano()
            notes.append(new_note)
        new_chord = chord.Chord(notes)
        new_chord.offset = offset
        output_notes.append(new_chord)
    else:
        new_note = note.Note(note_pattern)
        new_note.offset = offset
        new_note.storedInstrument = instrument.Piano()
        output_notes.append(new_note)
        
    offset += 0.5
    
if not os.path.exists(os.path.dirname(MIDI_OUTPUT_DIRECTORY)):
    os.makedirs(os.path.dirname(MIDI_OUTPUT_DIRECTORY))
midi_stream = stream.Stream(output_notes)
midi_stream.write('midi', fp="%s/%s.%s.%s" % (MIDI_OUTPUT_DIRECTORY, os.path.basename(CHECKPOINT_FILE), uuid.uuid4(), "mid"))
# Out:
# Epoch 1/500
# 25524/25524 [==============================] - 30s 1ms/step - loss: 3.5223
# Epoch 2/500
# 25524/25524 [==============================] - 29s 1ms/step - loss: 3.4550
# Epoch 3/500
# 25524/25524 [==============================] - 29s 1ms/step - loss: 3.3991
# Epoch 4/500
# 25524/25524 [==============================] - 29s 1ms/step - loss: 3.3360
# Epoch 5/500
# 16768/25524 [==================>...........] - ETA: 9s - loss: 3.2961
